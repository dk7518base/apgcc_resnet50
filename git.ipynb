# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/apgcc_res
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/apgcc_res'
# /content

# %%
# !git init
# !git config --global user.email "dk7518@g.skku.edu"
# !git config --global user.name "dk7518"
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/.git/

# %%
# !git add .
# !git commit -m "first commit"
# Out:
# [master (root-commit) 9d837fa] first commit
#  14 files changed, 2163 insertions(+)
#  create mode 100644 APGCC.py
#  create mode 100644 Decoder.py
#  create mode 100644 Encoder.py
#  create mode 100644 __init__.py
#  create mode 100644 build.py
#  create mode 100644 config.py
#  create mode 100644 dataset.py
#  create mode 100644 engine.py
#  create mode 100644 git.ipynb
#  create mode 100644 main.py
#  create mode 100644 resnet.py
#  create mode 100644 run.ipynb
#  create mode 100644 train.yml
#  create mode 100644 vgg.py

# %%
# !git remote rm origin

# %%
# !git remote add origin https://dk7518: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@github.com/dk7518/apgcc_code.git

# %%
# !git push origin master
# Out:
# Enumerating objects: 16, done.
# Counting objects: 100% (16/16), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (15/15), done.
# Writing objects: 100% (16/16), 123.21 KiB | 1.50 MiB/s, done.
# Total 16 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/dk7518/apgcc_code.git
#  * [new branch]      master -> master
